# %%
import pandas as pd

# %%
data = pd.read_csv('household.csv')
data.head()
# Out:
#    Unnamed: 0 자치구별(2)     연면적별(1)    시점  단독주택   아파트  연립주택 다세대주택 비거주용건물내
# 0           0     종로구      20㎡ 이하  2021   412  1272   159  1009      64
# 1           1     종로구   20㎡ ~ 40㎡  2021  1784  1549   306  3171      93
# 2           2     종로구   40㎡ ~ 60㎡  2021  1739  3527  1187  5555     106
# 3           3     종로구   60㎡ ~ 85㎡  2021  1367  5695  1795  2265     130
# 4           4     종로구  85㎡ ~ 100㎡  2021   686   493   278   222      88

# %%
data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
data.head()
# Out:
#   자치구별(2)     연면적별(1)    시점  단독주택   아파트  연립주택 다세대주택 비거주용건물내
# 0     종로구      20㎡ 이하  2021   412  1272   159  1009      64
# 1     종로구   20㎡ ~ 40㎡  2021  1784  1549   306  3171      93
# 2     종로구   40㎡ ~ 60㎡  2021  1739  3527  1187  5555     106
# 3     종로구   60㎡ ~ 85㎡  2021  1367  5695  1795  2265     130
# 4     종로구  85㎡ ~ 100㎡  2021   686   493   278   222      88

# %%
data.to_csv('household.csv')
