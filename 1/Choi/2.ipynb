# %%
# !pip install pandas
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the 'C:\Users\User\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd


h_t = pd.read_csv('h.csv')
hh_t = pd.read_csv('hh.csv')
sa_t = pd.read_csv('sa.csv')

# %%
test = pd.merge(h_t, hh_t, on = ['자치구', '시점'], how = 'inner')
test = pd.merge(test, sa_t, on = ['자치구', '시점'], how = 'inner')
test.head()
# Out:
#    자치구    시점   단독주택    아파트  연립주택  다세대주택  비거주용건물내    총 합   단독주택 비율    아파트 비율  \
# 0  종로구  2017  12920  14507  5451  11978      931  45787  0.282176  0.316837
# 1  종로구  2018  12699  14530  5428  12140      932  45729  0.277701  0.317741
# 2  종로구  2019  12421  15290  5459  12349      921  46440  0.267463  0.329242
# 3  종로구  2020  12259  15688  5460  12540      912  46859  0.261615  0.334792
# 4  종로구  2021  11987  15775  5490  12725      908  46885  0.255668  0.336462
#
#    ...  75~79세  80~84세  85세이상  전체인구수    청년층     청년층비율   중년층     중년층비율   노년층  \
# 0  ...     998     608    430  23638  11474  0.485405  6441  0.272485  5723
# 1  ...    1014     674    444  25326  13013  0.513820  6449  0.254640  5864
# 2  ...    1047     704    470  24671  12209  0.494873  6348  0.257306  6114
# 3  ...    1108     749    547  25983  12744  0.490475  6615  0.254590  6624
# 4  ...    1133     811    597  27308  13347  0.488758  6850  0.250842  7111
#
#       노년층비율
# 0  0.242110
# 1  0.231541
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 125 entries, 0 to 124
# Data columns (total 50 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   자치구         125 non-null    object
#  1   시점          125 non-null    int64
#  2   단독주택        125 non-null    int64
#  3   아파트         125 non-null    int64
#  4   연립주택        125 non-null    int64
#  5   다세대주택       125 non-null    int64
#  6   비거주용건물내     125 non-null    int64
#  7   총 합         125 non-null    int64
#  8   단독주택 비율     125 non-null    float64
#  9   아파트 비율      125 non-null    float64
#  10  연립주택 비율     125 non-null    float64
#  11  다세대주택 비율    125 non-null    float64
#  12  비거주용건물내 비율  125 non-null    float64
#  13  1인가구        125 non-null    int64
#  14  2인가구        125 non-null    int64
#  15  3인가구        125 non-null    int64
#  16  4인가구        125 non-null    int64
#  17  5인가구        125 non-null    int64
#  18  6인가구        125 non-null    int64
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 125 entries, 0 to 124
# Data columns (total 50 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   자치구         125 non-null    object
#  1   시점          125 non-null    int64
#  2   단독주택        125 non-null    int64
#  3   아파트         125 non-null    int64
#  4   연립주택        125 non-null    int64
#  5   다세대주택       125 non-null    int64
#  6   비거주용건물내     125 non-null    int64
#  7   총 합         125 non-null    int64
#  8   단독주택 비율     125 non-null    float64
#  9   아파트 비율      125 non-null    float64
#  10  연립주택 비율     125 non-null    float64
#  11  다세대주택 비율    125 non-null    float64
#  12  비거주용건물내 비율  125 non-null    float64
#  13  1인가구        125 non-null    int64
#  14  2인가구        125 non-null    int64
#  15  3인가구        125 non-null    int64
#  16  4인가구        125 non-null    int64
#  17  5인가구        125 non-null    int64
#  18  6인가구        125 non-null    int64
# ...

# %%
test = data.copy()
test = test[['자치구', '시점', '단독주택 비율', '아파트 비율', '연립주택 비율', '1인가구', '청년층', '중년층', '노년층']]
test.head()
# Out:
#    자치구    시점   단독주택 비율    아파트 비율   연립주택 비율   1인가구    청년층   중년층   노년층
# 0  종로구  2017  0.282176  0.316837  0.119051  23638  11474  6441  5723
# 1  종로구  2018  0.277701  0.317741  0.118699  25326  13013  6449  5864
# 2  종로구  2019  0.267463  0.329242  0.117550  24671  12209  6348  6114
# 3  종로구  2020  0.261615  0.334792  0.116520  25983  12744  6615  6624
# 4  종로구  2021  0.255668  0.336462  0.117095  27308  13347  6850  7111

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 125 entries, 0 to 124
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   자치구      125 non-null    object
#  1   시점       125 non-null    int64
#  2   단독주택 비율  125 non-null    float64
#  3   아파트 비율   125 non-null    float64
#  4   연립주택 비율  125 non-null    float64
#  5   1인가구     125 non-null    int64
#  6   청년층      125 non-null    int64
#  7   중년층      125 non-null    int64
#  8   노년층      125 non-null    int64
# dtypes: float64(3), int64(5), object(1)
# memory usage: 9.8+ KB

# %%
test1 = test.copy()

test1 = test1.loc[test1['시점'] == 2021]
test1.head(30)
# Out:
#       자치구    시점   단독주택 비율    아파트 비율   연립주택 비율    1인가구    청년층    중년층    노년층
# 4     종로구  2021  0.255668  0.336462  0.117095   27308  13347   6850   7111
# 9      중구  2021  0.138590  0.622108  0.044803   24544  11560   6242   6742
# 14    용산구  2021  0.181096  0.510054  0.051638   39270  19817  10347   9106
# 19    성동구  2021  0.108928  0.747971  0.021706   44946  22532  11327  11087
# 24    광진구  2021  0.165106  0.356232  0.045050   66140  38021  15157  12962
# 29   동대문구  2021  0.157143  0.637778  0.031519   65290  35548  13553  16189
# 34    중랑구  2021  0.157178  0.494820  0.038633   60487  21192  18531  20764
# 39    성북구  2021  0.154569  0.577766  0.044456   64985  34142  13779  17064
# 44    강북구  2021  0.176421  0.356449  0.049407   48428  15910  13738  18780
# 49    도봉구  2021  0.078261  0.604906  0.038913   37853  10713  11270  15870
# 54    노원구  2021  0.034426  0.864624  0.018093   60647  20526  15207  24914
# ...

# %%
test1.to_csv("test.csv", index = False)
